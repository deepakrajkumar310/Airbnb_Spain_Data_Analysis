# %% [markdown]
# ## Data Observation

# %% [markdown]
# It provides information about Airbnb listings in Madrid, Spain.

# %% [markdown]
# ## Loading the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading Data

# %%
airbnb_df = pd.read_csv("listings.csv")

# %%
airbnb_df.head()
# Out:
#       id                                      name    host_id host_name  \
# 0   6369  Rooftop terrace room ,  ensuite bathroom      13660     Simon
# 1  21853                      Bright and airy room      83531     Abdel
# 2  23001         Apartmento Arganzuela- Madrid Rio      82175     Jesus
# 3  24805                    Gran Via Studio Madrid  346366726         A
# 4  26825        Single Room whith private Bathroom     114340  Agustina
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0           Chamartín  Hispanoamérica  40.45724   -3.67688     Private room
# 1              Latina        Cármenes  40.40381   -3.74130     Private room
# 2          Arganzuela         Legazpi  40.38840   -3.69511  Entire home/apt
# 3              Centro     Universidad  40.42183   -3.70529  Entire home/apt
# 4          Arganzuela         Legazpi  40.38975   -3.69018     Private room
#
# ...

# %%
airbnb_df.tail()
# Out:
#              id                                         name    host_id  \
# 19613  49185822    Habitación con TV con Netflix en Lavapiés  172011610
# 19614  49186179  Habitación con TV con Netflix en Gaztambide  172011610
# 19615  49187258    Habitación con TV con Netflix en Chamberí  172011610
# 19616  49187471        Habitación con TV con Netflix en Goya  172011610
# 19617  49187791    Habitación con TV con Netflix en Chamberí  172011610
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 19613    Belaid              Centro   Embajadores  40.40756   -3.69937
# 19614    Belaid            Chamberí    Gaztambide  40.43706   -3.71364
# 19615    Belaid            Chamberí      Arapiles  40.43857   -3.70715
# 19616    Belaid           Salamanca    Guindalera  40.43027   -3.66759
# 19617    Belaid            Chamberí      Arapiles  40.43484   -3.70667
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19618 entries, 0 to 19617
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19618 non-null  int64
#  1   name                            19615 non-null  object
#  2   host_id                         19618 non-null  int64
#  3   host_name                       19091 non-null  object
#  4   neighbourhood_group             19618 non-null  object
#  5   neighbourhood                   19618 non-null  object
#  6   latitude                        19618 non-null  float64
#  7   longitude                       19618 non-null  float64
#  8   room_type                       19618 non-null  object
#  9   price                           19618 non-null  int64
#  10  minimum_nights                  19618 non-null  int64
#  11  number_of_reviews               19618 non-null  int64
# ...

# %%
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  1.961800e+04  1.961800e+04  19618.000000  19618.000000  19618.000000
# mean   2.912200e+07  1.312165e+08     40.420984     -3.694040    129.271740
# std    1.351839e+07  1.166790e+08      0.022627      0.028671    484.143545
# min    6.369000e+03  7.952000e+03     40.332210     -3.863910      0.000000
# 25%    1.903424e+07  2.765313e+07     40.409393     -3.707700     35.000000
# 50%    3.187506e+07  9.901898e+07     40.419735     -3.701120     58.000000
# 75%    4.090994e+07  2.256898e+08     40.430290     -3.685420    100.000000
# max    4.918779e+07  3.964281e+08     40.562740     -3.531900   9999.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    19618.000000       19618.000000       13981.000000
# mean         6.586196          31.858803           1.125958
# std         33.286582          63.938997           1.348235
# ...

# %%
airbnb_df.describe(include="O")
# Out:
#                       name host_name neighbourhood_group neighbourhood  \
# count                19615     19091               19618         19618
# unique               18793      3900                  21           128
# top     Habitación privada    Daniel              Centro   Embajadores
# freq                    22       255                8649          2318
#
#               room_type last_review
# count             19618       13981
# unique                4        1590
# top     Entire home/apt  2020-03-01
# freq              11314         359

# %% [markdown]
# ### Conclusion:
#
# It is observed that there are some null values in the data from info() function.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Exploring *"id"* column

# %%
airbnb_df["id"].nunique()
# Out:
# 19618

# %%
len(airbnb_df)
# Out:
# 19618

# %%
airbnb_df["id"].unique()
# Out:
# array([    6369,    21853,    23001, ..., 49187258, 49187471, 49187791],
#       dtype=int64)

# %% [markdown]
# #### Conclusion:
#
# The number of unique values of airbnb's identifier for the listing is equal to the length of the dataframe, which means that there is no repetition of data and that implies that there are no duplicate rows in the data.

# %% [markdown]
# ### Exploring *"host_id"* column

# %%
airbnb_df["host_id"].nunique()
# Out:
# 11325

# %%
len(airbnb_df)
# Out:
# 19618

# %% [markdown]
# #### Conclusion:
#
# It can be observed that there has been some repetition of host_id which means that some of the hosts have more than one airbnb listing.

# %% [markdown]
# ### Exploring *"host_name"* column

# %%
airbnb_df["host_name"].nunique()
# Out:
# 3900

# %%
airbnb_df["host_name"].value_counts()
# Out:
# Daniel                255
# Carlos                231
# Javier                230
# Maria                 192
# Ana                   186
#                      ...
# Bernardo                1
# Cedric                  1
# Ricky                   1
# Maria Laura Teresa      1
# Y                       1
# Name: host_name, Length: 3900, dtype: int64

# %% [markdown]
# #### Conclusion:
#
# It can be observed that some names are repeated in the column. But this does not provide any useful analytical information.
# So, we can remove this column from further analysis.

# %% [markdown]
# ### Exploring *"neighbourhood_group"* column

# %%
airbnb_df["neighbourhood_group"].nunique()
# Out:
# 21

# %%
airbnb_df["neighbourhood_group"].unique()
# Out:
# array(['Chamartín', 'Latina', 'Arganzuela', 'Centro', 'Salamanca',
#        'Fuencarral - El Pardo', 'Puente de Vallecas', 'Ciudad Lineal',
#        'Chamberí', 'Villaverde', 'Hortaleza', 'Moncloa - Aravaca',
#        'Carabanchel', 'Tetuán', 'Retiro', 'San Blas - Canillejas',
#        'Villa de Vallecas', 'Barajas', 'Usera', 'Moratalaz', 'Vicálvaro'],
#       dtype=object)

# %%
airbnb_df["neighbourhood_group"].value_counts()
# Out:
# Centro                   8649
# Salamanca                1324
# Chamberí                 1252
# Arganzuela               1104
# Tetuán                    816
# Carabanchel               708
# Retiro                    664
# Ciudad Lineal             649
# Puente de Vallecas        617
# Latina                    608
# Chamartín                 580
# Moncloa - Aravaca         554
# San Blas - Canillejas     497
# Hortaleza                 364
# Fuencarral - El Pardo     315
# Usera                     280
# Villaverde                177
# Barajas                   172
# Moratalaz                 118
# Villa de Vallecas          98
# Vicálvaro                  72
# Name: neighbourhood_group, dtype: int64

# %%
airbnb_df["neighbourhood_group"].value_counts(normalize=True)*100
# Out:
# Centro                   44.087063
# Salamanca                 6.748904
# Chamberí                  6.381894
# Arganzuela                5.627485
# Tetuán                    4.159445
# Carabanchel               3.608931
# Retiro                    3.384647
# Ciudad Lineal             3.308186
# Puente de Vallecas        3.145071
# Latina                    3.099195
# Chamartín                 2.956469
# Moncloa - Aravaca         2.823937
# San Blas - Canillejas     2.533388
# Hortaleza                 1.855439
# Fuencarral - El Pardo     1.605668
# Usera                     1.427261
# Villaverde                0.902233
# Barajas                   0.876746
# Moratalaz                 0.601488
# Villa de Vallecas         0.499541
# Vicálvaro                 0.367010
# Name: neighbourhood_group, dtype: float64

# %%
plt.figure(figsize=(35,15))
sns.countplot(x=airbnb_df["neighbourhood_group"])

plt.title("Count plot of neighbourhood_group",y=1.02)
plt.xlabel("neighbourhood_group")
plt.show()

# %%
plt.figure(figsize=(20,20))
count = [8649,1324,1252,1104,816,708,664,649,617,608,580,554,497,364,315,280,177,172,118,98,72]
plt.pie(count,labels=["Centro","Salamanca","Chamberí","Arganzuela","Tetuán","Carabanchel","Retiro","Ciudad Lineal","Puente de Vallecas","Latina","Chamartín","Moncloa - Aravaca","San Blas - Canillejas","Hortaleza","Fuencarral - El Pardo","Usera","Villaverde","Barajas","Moratalaz","Villa de Vallecas","Vicálvaro"],autopct="%1.1f%%")

plt.title("Pie chart of neighbourhood_group",y=1.02)
plt.legend()
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * Most of the listings are located at *centro* region which are 8649 and that constitute of 44.1% of total listings.
# * This **neighbourhood_group** might have an impact on the price and hence further exploration with other columns is required.

# %% [markdown]
# ### Exploring *"neighbourhood"* column

# %%
airbnb_df["neighbourhood"].nunique()
# Out:
# 128

# %%
airbnb_df["neighbourhood"].value_counts()
# Out:
# Embajadores      2318
# Universidad      1869
# Palacio          1506
# Sol              1125
# Justicia          951
#                  ...
# Valdemarín          5
# Fuentelareina       5
# El Pardo            3
# Horcajo             2
# Atalaya             1
# Name: neighbourhood, Length: 128, dtype: int64

# %%
airbnb_df["neighbourhood"].value_counts(normalize=True)*100
# Out:
# Embajadores      11.815679
# Universidad       9.526965
# Palacio           7.676624
# Sol               5.734530
# Justicia          4.847589
#                    ...
# Valdemarín        0.025487
# Fuentelareina     0.025487
# El Pardo          0.015292
# Horcajo           0.010195
# Atalaya           0.005097
# Name: neighbourhood, Length: 128, dtype: float64

# %% [markdown]
# #### Conclusion:
#
# * Most of the listings are located at *Embajadores* neighbourhood which are 2318 and that constitute of 11.8% of total listings.
# * We can further explore this column along with *neighbourhood_group* column so as to locate to which neighbourhood_group these neighbourhoods may belong.
# * The **neighbourhood** column might also have an impact on the price.

# %% [markdown]
# ### Exploring *"latitude"* column

# %%
airbnb_df["latitude"].mean()
# Out:
# 40.42098379804261

# %%
airbnb_df["latitude"].min()
# Out:
# 40.33221

# %%
airbnb_df["latitude"].max()
# Out:
# 40.56274

# %%
airbnb_df["latitude"].median()
# Out:
# 40.419735

# %%
airbnb_df["latitude"].std()
# Out:
# 0.022626926667915506

# %%
airbnb_df["latitude"].var()
# Out:
# 0.0005119778104352259

# %%
airbnb_df["latitude"].skew()
# Out:
# 0.44439622092520875

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(airbnb_df["latitude"],color="maroon")

plt.title("Histogram plot of latitude",y=1.02)
plt.xlabel("latitude")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(airbnb_df["latitude"],kind="kde",color="orange")

plt.title("Density plot of latitude",y=1.02)
plt.xlabel("latitude")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
airbnb_df["latitude"].quantile(0.10),airbnb_df["latitude"].quantile(0.25),airbnb_df["latitude"].quantile(0.50),airbnb_df["latitude"].quantile(0.75),airbnb_df["latitude"].quantile(0.90)
# Out:
# (40.395931000000004, 40.4093925, 40.419735, 40.43029, 40.450533)

# %%
sns.boxplot(airbnb_df["latitude"],orient="h",color="lavender")

plt.title("Box plot for latitude",y=1.02)
plt.xlabel("latitude")
plt.show()

# %%
sns.violinplot(airbnb_df["latitude"],orient="h",color="lightblue")

plt.title("Violin plot for latitude",y=1.02)
plt.xlabel("latitude")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **latitude** has a symmetrical distribution i.e., it is not skewed and has a skewness value of 0.444
#
# * The Density curve of *latitude* column is centered along mean 40.421 with standard deviation of 0.022.
# * The range of the latitude is from 40.33221 to 40.56274.
# * Most of the listings are in the latitude of 40.4 to 40.45.
# * 10% of listings are in the latitude of 40.395 and below.
# * 25% of listings are in the latitude of 40.409 and below.
# * 50% of listings are in the latitude of 40.419 and below.
# * 75% of listings are in the latitude of 40.43 and below.
# * 90% of listings are in the latitude of 40.45 and below.
# * *latitude* column is having outliers (i.e., extreme values) towards both lower and higher sides.
#
# **latitude** column can be further explored with other columns

# %% [markdown]
# ### Exploring *"longitude"* column

# %%
airbnb_df["longitude"].mean()
# Out:
# -3.6940399525945566

# %%
airbnb_df["longitude"].min()
# Out:
# -3.86391

# %%
airbnb_df["longitude"].max()
# Out:
# -3.5319

# %%
airbnb_df["longitude"].median()
# Out:
# -3.70112

# %%
airbnb_df["longitude"].std()
# Out:
# 0.02867128726185069

# %%
airbnb_df["longitude"].var()
# Out:
# 0.0008220427132515617

# %%
airbnb_df["longitude"].skew()
# Out:
# 1.2856774993431148

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(airbnb_df["longitude"],color="navy")

plt.title("Histogram plot of total longitude",y=1.02)
plt.xlabel("longitude")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(airbnb_df["longitude"],kind="kde",color="lightgreen")

plt.title("Density plot of longitude",y=1.02)
plt.xlabel("longitude")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
airbnb_df["longitude"].quantile(0.10),airbnb_df["longitude"].quantile(0.25),airbnb_df["longitude"].quantile(0.50),airbnb_df["longitude"].quantile(0.75),airbnb_df["longitude"].quantile(0.90)
# Out:
# (-3.715453, -3.7077, -3.70112, -3.68542, -3.658681)

# %%
sns.boxplot(airbnb_df["longitude"],orient="h",color="lime")

plt.title("Box plot for longitude",y=1.02)
plt.xlabel("longitude")
plt.show()

# %%
sns.violinplot(airbnb_df["longitude"],orient="h",color="olive")

plt.title("Violin plot for longitude",y=1.02)
plt.xlabel("longitude")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **longitude** has an asymmetrical distribution i.e., it is skewed with a skewness value of 1.285
#
# * The Density curve of *longitude* column is centered along mean -3.694 with standard deviation of 0.028.
# * The range of the longitude is from -3.86391 to -3.5319.
# * Most of the listings are in the longitude of -3.72 to -3.68.
# * 10% of listings are in the longitude of -3.715 and below.
# * 25% of listings are in the longitude of -3.707 and below.
# * 50% of listings are in the longitude of -3.701 and below.
# * 75% of listings are in the longitude of -3.685 and below.
# * 90% of listings are in the longitude of -3.658 and below.
# * *longitude* column is having outliers (i.e., extreme values) towards both lower and higher sides.
#
# **longitude** column can be further explored with other columns

# %% [markdown]
# ### Exploring *"room_type"* column

# %%
airbnb_df["room_type"].nunique()
# Out:
# 4

# %%
airbnb_df["room_type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
airbnb_df["room_type"].value_counts()
# Out:
# Entire home/apt    11314
# Private room        7809
# Shared room          329
# Hotel room           166
# Name: room_type, dtype: int64

# %%
airbnb_df["room_type"].value_counts(normalize=True)*100
# Out:
# Entire home/apt    57.671526
# Private room       39.805281
# Shared room         1.677031
# Hotel room          0.846162
# Name: room_type, dtype: float64

# %%
sns.countplot(x=airbnb_df["room_type"])

plt.title("Count plot of room_type",y=1.02)
plt.xlabel("room_type")
plt.show()

# %%
count = [11314,7809,329,166]
plt.pie(count,labels=["Entire home/apt","Private room","Shared room","Hotel room"],autopct="%1.1f%%")

plt.title("Pie chart of room_type",y=1.02)
plt.legend()
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * Most of the *room_types* are of Entire home/apt with 11314 listings which constitute of 57.7% of total listings.
# * The next most available *room_types* are private rooms with 7809 listings which constitute of 38.8% of total listings.
# * Shared rooms and Hotel rooms are least available compared to the previous room types.
# * We can further explore this column with other columns.
# * The **room_type** column might also have an impact on the price.

# %% [markdown]
# ### Exploring *"price"* column

# %%
airbnb_df["price"].mean()
# Out:
# 129.27174023855642

# %%
airbnb_df["price"].min()
# Out:
# 0

# %%
airbnb_df["price"].max()
# Out:
# 9999

# %%
airbnb_df["price"].median()
# Out:
# 58.0

# %%
airbnb_df["price"].std()
# Out:
# 484.143544651945

# %%
airbnb_df["price"].var()
# Out:
# 234394.97182814986

# %%
airbnb_df["price"].skew()
# Out:
# 15.448872477202384

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(airbnb_df["price"],color="purple")

plt.title("Histogram plot of price",y=1.02)
plt.xlabel("price")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(airbnb_df["price"],kind="kde",color="red")

plt.title("Density plot of price",y=1.02)
plt.xlabel("price")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
airbnb_df["price"].quantile(0.10),airbnb_df["price"].quantile(0.25),airbnb_df["price"].quantile(0.50),airbnb_df["price"].quantile(0.75),airbnb_df["price"].quantile(0.90)
# Out:
# (21.0, 35.0, 58.0, 100.0, 191.0)

# %%
sns.boxplot(airbnb_df["price"],orient="h")

plt.title("Box plot for price",y=1.02)
plt.xlabel("price")
plt.show()

# %%
sns.violinplot(airbnb_df["price"],orient="h",color="sienna")

plt.title("Violin plot for price",y=1.02)
plt.xlabel("price")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **price** has an asymmetrical distribution i.e., it is skewed with a skewness value of 15.448
#
# * The Density curve of column is centered along mean 129.271 with standard deviation of 484.143.
# * The range of values is from 0 to 9999.
# * Most of the price in the range from 0 to 200.
# * 10% of price is 21 and below.
# * 25% of price is 35 and below.
# * 50% of price is 58 and below.
# * 75% of price is 100 and below.
# * 90% of price is 191 and below.
# * *price* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"minimum_nights"* column

# %%
airbnb_df["minimum_nights"].mean()
# Out:
# 6.58619635029055

# %%
airbnb_df["minimum_nights"].min()
# Out:
# 1

# %%
airbnb_df["minimum_nights"].max()
# Out:
# 1125

# %%
airbnb_df["minimum_nights"].median()
# Out:
# 2.0

# %%
airbnb_df["minimum_nights"].std()
# Out:
# 33.286582453618756

# %%
airbnb_df["minimum_nights"].var()
# Out:
# 1107.9965714415598

# %%
airbnb_df["minimum_nights"].skew()
# Out:
# 20.979676122152036

# %% [markdown]
# #### Looking at the Distribution of column

# %%
plt.figure(figsize=(10,2))
sns.histplot(airbnb_df["minimum_nights"],color="teal")

plt.title("Histogram plot of minimum_nights",y=1.02)
plt.xlabel("minimum_nights")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(airbnb_df["minimum_nights"],kind="kde",color="tan")

plt.title("Density plot of minimum_nights",y=1.02)
plt.xlabel("minimum_nights")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
airbnb_df["minimum_nights"].quantile(0.10),airbnb_df["minimum_nights"].quantile(0.25),airbnb_df["minimum_nights"].quantile(0.50),airbnb_df["minimum_nights"].quantile(0.75),airbnb_df["minimum_nights"].quantile(0.90)
# Out:
# (1.0, 1.0, 2.0, 3.0, 10.0)

# %%
sns.boxplot(airbnb_df["minimum_nights"],orient="h",color="tomato")

plt.title("Box plot for minimum_nights",y=1.02)
plt.xlabel("minimum_nights")
plt.show()

# %%
sns.violinplot(airbnb_df["minimum_nights"],orient="h",color="turquoise")

plt.title("Violin plot for minimum_nights",y=1.02)
plt.xlabel("minimum_nights")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **minimum_nights** has an asymmetrical distribution i.e., it is skewed with a skewness value of 20.979
#
# * The Density curve of column is centered along mean 6.58 with standard deviation of 33.286.
# * The range of values is from 1 to 1125.
# * Most of the listings have minimum number of night stay in the range from 1 to 10.
# * 25% of the listings have minimum number of night stay of 1.
# * 50% of the listings have minimum number of night stay of 2 and below.
# * 75% of the listings have minimum number of night stay of 3 and below.
# * 90% of the listings have minimum number of night stay of 10 and below.
# * *minimum_nights* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"number_of_reviews"* column

# %%
airbnb_df["number_of_reviews"].mean()
# Out:
# 31.858803139973492

# %%
airbnb_df["number_of_reviews"].min()
# Out:
# 0

# %%
airbnb_df["number_of_reviews"].max()
# Out:
# 706

# %%
airbnb_df["number_of_reviews"].median()
# Out:
# 4.0

# %%
airbnb_df["number_of_reviews"].std()
# Out:
# 63.93899737932481

# %%
airbnb_df["number_of_reviews"].var()
# Out:
# 4088.195385873305

# %%
airbnb_df["number_of_reviews"].skew()
# Out:
# 3.4393256274261153

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(airbnb_df["number_of_reviews"],color="violet")

plt.title("Histogram plot of number_of_reviews",y=1.02)
plt.xlabel("number_of_reviews")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(airbnb_df["number_of_reviews"],kind="kde",color="yellow")

plt.title("Density plot of number_of_reviews",y=1.02)
plt.xlabel("number_of_reviews")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
airbnb_df["number_of_reviews"].quantile(0.10),airbnb_df["number_of_reviews"].quantile(0.25),airbnb_df["number_of_reviews"].quantile(0.50),airbnb_df["number_of_reviews"].quantile(0.75),airbnb_df["number_of_reviews"].quantile(0.90)
# Out:
# (0.0, 0.0, 4.0, 31.0, 102.0)

# %%
sns.boxplot(airbnb_df["number_of_reviews"],orient="h",color="yellowgreen")

plt.title("Box plot for number_of_reviews",y=1.02)
plt.xlabel("number_of_reviews")
plt.show()

# %%
sns.violinplot(airbnb_df["number_of_reviews"],orient="h",color="lavender")

plt.title("Violin plot for number_of_reviews",y=1.02)
plt.xlabel("number_of_reviews")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **number_of_reviews** has an asymmetrical distribution i.e., it is skewed with a skewness value of 3.439
#
# * The Density curve of column is centered along mean 31.858 with standard deviation of 63.938.
# * The range of values is from 0 to 706.
# * Most of the listings have number_of_reviews in the range from 0 to 100.
# * 25% of the listings have no reviews at all.
# * 50% of the listings have number_of_reviews of 4 and below.
# * 75% of the listings have number_of_reviews of 31 and below.
# * 90% of the listings have number_of_reviews of 102 and below.
# * *number_of_reviews* column is having outliers (i.e., extreme values) towards higher side.
#
# **number_of_reviews** might have an impact on price

# %% [markdown]
# ### Exploring *"reviews_per_month"* column

# %%
airbnb_df["reviews_per_month"].mean()
# Out:
# 1.1259580859738214

# %%
airbnb_df["reviews_per_month"].min()
# Out:
# 0.01

# %%
airbnb_df["reviews_per_month"].max()
# Out:
# 16.22

# %%
airbnb_df["reviews_per_month"].median()
# Out:
# 0.59

# %%
airbnb_df["reviews_per_month"].std()
# Out:
# 1.348234666564291

# %%
airbnb_df["reviews_per_month"].var()
# Out:
# 1.8177367161257252

# %%
airbnb_df["reviews_per_month"].skew()
# Out:
# 2.0515851873229796

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(airbnb_df["reviews_per_month"],color="orange")

plt.title("Histogram plot of reviews_per_month",y=1.02)
plt.xlabel("reviews_per_month")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(airbnb_df["reviews_per_month"],kind="kde",color="green")

plt.title("Density plot of reviews_per_month",y=1.02)
plt.xlabel("reviews_per_month")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
airbnb_df["reviews_per_month"].quantile(0.10),airbnb_df["reviews_per_month"].quantile(0.25),airbnb_df["reviews_per_month"].quantile(0.50),airbnb_df["reviews_per_month"].quantile(0.75),airbnb_df["reviews_per_month"].quantile(0.90)
# Out:
# (0.06, 0.17, 0.59, 1.63, 3.0)

# %%
sns.boxplot(airbnb_df["reviews_per_month"],orient="h",color="skyblue")

plt.title("Box plot for reviews_per_month",y=1.02)
plt.xlabel("reviews_per_month")
plt.show()

# %%
sns.violinplot(airbnb_df["reviews_per_month"],orient="h",color="magenta")

plt.title("Violin plot for reviews_per_month",y=1.02)
plt.xlabel("reviews_per_month")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **reviews_per_month** has an asymmetrical distribution i.e., it is skewed with a skewness value of 2.051
#
# * The Density curve of column is centered along mean 1.125 with standard deviation of 1.348.
# * The range of values is from 0.01 to 16.22.
# * Most of the listings have reviews_per_month in the range from 0 to 2.5.
# * 10% of the listings have reviews_per_month of 0.06 and below.
# * 25% of the listings have reviews_per_month of 0.17 and below.
# * 50% of the listings have reviews_per_month of 0.59 and below.
# * 75% of the listings have reviews_per_month of 1.63 and below.
# * 90% of the listings have reviews_per_month of 3 and below.
# * *reviews_per_month* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"calculated_host_listings_count"* column

# %%
airbnb_df["calculated_host_listings_count"].mean()
# Out:
# 10.229177286165767

# %%
airbnb_df["calculated_host_listings_count"].min()
# Out:
# 1

# %%
airbnb_df["calculated_host_listings_count"].max()
# Out:
# 163

# %%
airbnb_df["calculated_host_listings_count"].median()
# Out:
# 2.0

# %%
airbnb_df["calculated_host_listings_count"].std()
# Out:
# 23.546471854519076

# %%
airbnb_df["calculated_host_listings_count"].var()
# Out:
# 554.436336795659

# %%
airbnb_df["calculated_host_listings_count"].skew()
# Out:
# 4.014938390833173

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(airbnb_df["calculated_host_listings_count"],color="tomato")

plt.title("Histogram plot of calculated_host_listings_count",y=1.02)
plt.xlabel("calculated_host_listings_count")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(airbnb_df["calculated_host_listings_count"],kind="kde",color="red")

plt.title("Density plot of calculated_host_listings_count",y=1.02)
plt.xlabel("calculated_host_listings_count")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
airbnb_df["calculated_host_listings_count"].quantile(0.10),airbnb_df["calculated_host_listings_count"].quantile(0.25),airbnb_df["calculated_host_listings_count"].quantile(0.50),airbnb_df["calculated_host_listings_count"].quantile(0.75),airbnb_df["calculated_host_listings_count"].quantile(0.90)
# Out:
# (1.0, 1.0, 2.0, 6.0, 26.0)

# %%
sns.boxplot(airbnb_df["calculated_host_listings_count"],orient="h",color="ivory")

plt.title("Box plot for calculated_host_listings_count",y=1.02)
plt.xlabel("calculated_host_listings_count")
plt.show()

# %%
sns.violinplot(airbnb_df["calculated_host_listings_count"],orient="h",color="cyan")

plt.title("Violin plot for calculated_host_listings_count",y=1.02)
plt.xlabel("calculated_host_listings_count")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **calculated_host_listings_count** has an asymmetrical distribution i.e., it is skewed with a skewness value of 4.015
#
# * The Density curve of column is centered along mean 10.229 with standard deviation of 23.546.
# * The range of values is from 1 to 163.
# * In most of the cases the number of listings the host has are in the range from 1 to 20.
# * 25% of the cases the number of listings the host has is 1 and below.
# * 50% of the cases the number of listings the host has is 2 and below.
# * 75% of the cases the number of listings the host has is 6 and below.
# * 90% of the cases the number of listings the host has is 26 and below.
# * *calculated_host_listings_count* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"availability_365"* column

# %%
airbnb_df["availability_365"].mean()
# Out:
# 159.09832806606178

# %%
airbnb_df["availability_365"].min()
# Out:
# 0

# %%
airbnb_df["availability_365"].max()
# Out:
# 365

# %%
airbnb_df["availability_365"].median()
# Out:
# 126.0

# %%
airbnb_df["availability_365"].std()
# Out:
# 144.2528025613528

# %%
airbnb_df["availability_365"].var()
# Out:
# 20808.871046804637

# %%
airbnb_df["availability_365"].skew()
# Out:
# 0.265017395235626

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(airbnb_df["availability_365"],color="purple")

plt.title("Histogram plot of availability_365",y=1.02)
plt.xlabel("availability_365")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(airbnb_df["availability_365"],kind="kde",color="blue")

plt.title("Density plot of availability_365",y=1.02)
plt.xlabel("availability_365")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
airbnb_df["availability_365"].quantile(0.10),airbnb_df["availability_365"].quantile(0.25),airbnb_df["availability_365"].quantile(0.50),airbnb_df["availability_365"].quantile(0.75),airbnb_df["availability_365"].quantile(0.90)
# Out:
# (0.0, 0.0, 126.0, 320.0, 364.0)

# %%
sns.boxplot(airbnb_df["availability_365"],orient="h",color="khaki")

plt.title("Box plot for availability_365",y=1.02)
plt.xlabel("availability_365")
plt.show()

# %%
sns.violinplot(airbnb_df["availability_365"],orient="h",color="grey")

plt.title("Violin plot for availability_365",y=1.02)
plt.xlabel("availability_365")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **availability_365** has a symmetrical distribution i.e., it is not skewed and has a skewness value of 0.265
#
# * The Density curve of column is multimodal.
# * The range of values is from 0 to 365.
# * 25% of the cases the availability of listings is 0 i.e., there is no availability.
# * 50% of the cases the availability of listings is 126 and below.
# * 75% of the cases the availability of listings is 320 and below.
# * 90% of the cases the availability of listings is 364 and below.
# * *availability_365* column is having no outliers (i.e., extreme values).

# %% [markdown]
# ### Exploring different columns in conjunction

# %%
sns.scatterplot(data=airbnb_df, x="latitude", y="longitude", hue="neighbourhood_group")

plt.title("Scatter plot for neighbourhood_group",y=1.02)
plt.show()

# %%
sns.scatterplot(data=airbnb_df, x="latitude", y="longitude", hue="neighbourhood")

plt.title("Scatter plot for neighbourhood",y=1.02)
plt.show()

# %%
plt.figure(figsize=(35,15))
sns.countplot(data=airbnb_df, x="neighbourhood_group", hue="neighbourhood")

plt.title("Count plot of neighbourhood",y=1.02)
plt.show()

# %%
sns.scatterplot(data=airbnb_df, x="latitude", y="longitude", hue="room_type")

plt.title("Scatter plot for room_type",y=1.02)
plt.show()

# %%
sns.scatterplot(data=airbnb_df, x="latitude", y="longitude", hue="availability_365")

plt.title("Scatter plot for availability_365",y=1.02)
plt.show()

# %%
sns.scatterplot(data=airbnb_df, x="latitude", y="longitude", hue="room_type", size="availability_365")

plt.title("Scatter plot for availability_365",y=1.02)
plt.show()

# %%
from wordcloud import WordCloud

# %%
text = " ".join(airbnb_df["neighbourhood_group"].to_list())
wordcloud = WordCloud().generate_from_text(text)

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()

# %%
text = " ".join(airbnb_df["neighbourhood"].to_list())
wordcloud = WordCloud(background_color="salmon").generate_from_text(text)

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * Different columns i.e., *latitude*, *longitude*, *neighbourhood_group*, *neighbourhood* and *availability_365* have been explored in conjunction.
# * The neighbourhood_groups and neighbourhoods have been plotted at their respective latitudes and longitudes using *scatterplot*.
# * Also room types and availability with respect to different latitudes and longitudes are plotted.
# * The most occuring listings of the neighbourhood_groups and neighbourhoods have been represented using *wordcloud*.

# %% [markdown]
# ### Plotting Heat Map

# %%
data = airbnb_df[['latitude','longitude','price','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']].corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data,cmap="mako",annot=True,linewidth=.5)

plt.title("Heat Map",y=1.02)
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * The correlation between the columns has been explored.

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Handling duplicate data

# %%
airbnb_df.shape
# Out:
# (19618, 16)

# %%
airbnb_df.drop_duplicates().shape
# Out:
# (19618, 16)

# %%
airbnb_df
# Out:
#              id                                         name    host_id  \
# 0          6369     Rooftop terrace room ,  ensuite bathroom      13660
# 1         21853                         Bright and airy room      83531
# 2         23001            Apartmento Arganzuela- Madrid Rio      82175
# 3         24805                       Gran Via Studio Madrid  346366726
# 4         26825           Single Room whith private Bathroom     114340
# ...         ...                                          ...        ...
# 19613  49185822    Habitación con TV con Netflix en Lavapiés  172011610
# 19614  49186179  Habitación con TV con Netflix en Gaztambide  172011610
# 19615  49187258    Habitación con TV con Netflix en Chamberí  172011610
# 19616  49187471        Habitación con TV con Netflix en Goya  172011610
# 19617  49187791    Habitación con TV con Netflix en Chamberí  172011610
#
#       host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# ...

# %% [markdown]
# #### Insights:
#
# It is identified that there are no duplicate rows in the data.

# %% [markdown]
# ### Checking null values

# %%
airbnb_df.isnull().sum()
# Out:
# id                                   0
# name                                 3
# host_id                              0
# host_name                          527
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       5637
# reviews_per_month                 5637
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
airbnb_df.drop(columns=["name","host_name","last_review"],inplace=True,axis=1)
airbnb_df.head()
# Out:
#       id    host_id neighbourhood_group   neighbourhood  latitude  longitude  \
# 0   6369      13660           Chamartín  Hispanoamérica  40.45724   -3.67688
# 1  21853      83531              Latina        Cármenes  40.40381   -3.74130
# 2  23001      82175          Arganzuela         Legazpi  40.38840   -3.69511
# 3  24805  346366726              Centro     Universidad  40.42183   -3.70529
# 4  26825     114340          Arganzuela         Legazpi  40.38975   -3.69018
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room     60               1                 78
# 1     Private room     31               4                 33
# 2  Entire home/apt     50              15                  0
# 3  Entire home/apt     92               5                 10
# 4     Private room     26               2                149
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %%
airbnb_df["reviews_per_month"].fillna(airbnb_df["reviews_per_month"].median(),inplace=True)

# %%
airbnb_df.isnull().sum()
# Out:
# id                                0
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
airbnb_df.shape
# Out:
# (19618, 13)

# %% [markdown]
# #### Insights:
#
# * *name*, *host_name* and *last_review* columns have been removed as they are of no significance.
# * Apart from that, there are some missing values in the *reviews_per_month* column which are filled using the median of the column using **fillna()** function.

# %% [markdown]
# ### Handling outliers

# %% [markdown]
# #### *price* column

# %%
airbnb_df = airbnb_df[airbnb_df["price"] <= 500]

# %%
airbnb_df[airbnb_df["price"] > 500]
# Out:
# Empty DataFrame
# Columns: [id, host_id, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# #### *minimum_nights* column

# %%
airbnb_df = airbnb_df[airbnb_df["minimum_nights"] <= 40]

# %% [markdown]
# #### *number_of_reviews* column

# %%
airbnb_df = airbnb_df[airbnb_df["number_of_reviews"] <= 150]

# %% [markdown]
# #### *reviews_per_month* column

# %%
airbnb_df = airbnb_df[airbnb_df["reviews_per_month"] <= 5]

# %% [markdown]
# #### *calculated_host_listings_count* column

# %%
airbnb_df = airbnb_df[airbnb_df["calculated_host_listings_count"] <= 30]

# %%
airbnb_df
# Out:
#              id    host_id neighbourhood_group   neighbourhood  latitude  \
# 0          6369      13660           Chamartín  Hispanoamérica  40.45724
# 1         21853      83531              Latina        Cármenes  40.40381
# 2         23001      82175          Arganzuela         Legazpi  40.38840
# 3         24805  346366726              Centro     Universidad  40.42183
# 4         26825     114340          Arganzuela         Legazpi  40.38975
# ...         ...        ...                 ...             ...       ...
# 19613  49185822  172011610              Centro     Embajadores  40.40756
# 19614  49186179  172011610            Chamberí      Gaztambide  40.43706
# 19615  49187258  172011610            Chamberí        Arapiles  40.43857
# 19616  49187471  172011610           Salamanca      Guindalera  40.43027
# 19617  49187791  172011610            Chamberí        Arapiles  40.43484
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
airbnb_df.reset_index(drop=True,inplace=True)
airbnb_df
# Out:
#              id    host_id neighbourhood_group   neighbourhood  latitude  \
# 0          6369      13660           Chamartín  Hispanoamérica  40.45724
# 1         21853      83531              Latina        Cármenes  40.40381
# 2         23001      82175          Arganzuela         Legazpi  40.38840
# 3         24805  346366726              Centro     Universidad  40.42183
# 4         26825     114340          Arganzuela         Legazpi  40.38975
# ...         ...        ...                 ...             ...       ...
# 16003  49185822  172011610              Centro     Embajadores  40.40756
# 16004  49186179  172011610            Chamberí      Gaztambide  40.43706
# 16005  49187258  172011610            Chamberí        Arapiles  40.43857
# 16006  49187471  172011610           Salamanca      Guindalera  40.43027
# 16007  49187791  172011610            Chamberí        Arapiles  40.43484
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %% [markdown]
# #### Insights:
#
# The outliers have been handled in the respective columns by applying filtering condition.

# %% [markdown]
# ### Handling categorical values

# %%
first_condition = (airbnb_df["neighbourhood_group"].value_counts())/len(airbnb_df)
second_condition = (airbnb_df["neighbourhood"].value_counts())/len(airbnb_df)

airbnb_df["neighbourhood_group_encode"] = airbnb_df["neighbourhood_group"].apply(lambda x : first_condition[x])
airbnb_df["neighbourhood_encode"] = airbnb_df["neighbourhood"].apply(lambda y : second_condition[y])

# %%
airbnb_df.drop(columns=["neighbourhood_group","neighbourhood"],inplace=True,axis=1)
airbnb_df.head()
# Out:
#       id    host_id  latitude  longitude        room_type  price  \
# 0   6369      13660  40.45724   -3.67688     Private room     60
# 1  21853      83531  40.40381   -3.74130     Private room     31
# 2  23001      82175  40.38840   -3.69511  Entire home/apt     50
# 3  24805  346366726  40.42183   -3.70529  Entire home/apt     92
# 4  26825     114340  40.38975   -3.69018     Private room     26
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                 78               0.58
# 1               4                 33               0.42
# 2              15                  0               0.59
# 3               5                 10               0.13
# 4               2                149               1.12
#
#    calculated_host_listings_count  availability_365  \
# 0                               1               180
# 1                               2               364
# 2                               7                 1
# ...

# %%
airbnb_df = pd.get_dummies(airbnb_df,columns=["room_type"])
airbnb_df
# Out:
#              id    host_id  latitude  longitude  price  minimum_nights  \
# 0          6369      13660  40.45724   -3.67688     60               1
# 1         21853      83531  40.40381   -3.74130     31               4
# 2         23001      82175  40.38840   -3.69511     50              15
# 3         24805  346366726  40.42183   -3.70529     92               5
# 4         26825     114340  40.38975   -3.69018     26               2
# ...         ...        ...       ...        ...    ...             ...
# 16003  49185822  172011610  40.40756   -3.69937     23              30
# 16004  49186179  172011610  40.43706   -3.71364     21              30
# 16005  49187258  172011610  40.43857   -3.70715     22               7
# 16006  49187471  172011610  40.43027   -3.66759     19              30
# 16007  49187791  172011610  40.43484   -3.70667     20              30
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
airbnb_df.shape
# Out:
# (16008, 16)

# %% [markdown]
# #### Insights:
#
# The *neighbourhood_group* and *neighbourhood* columns have been handled using **frequency encoding** and the *room_type* column has been handled using **one hot encoding**.

# %% [markdown]
# ### Handling numerical values

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
airbnb_df[["price","minimum_nights","number_of_reviews","reviews_per_month","calculated_host_listings_count"]] = scaler.fit_transform(airbnb_df[["price","minimum_nights","number_of_reviews","reviews_per_month","calculated_host_listings_count"]])
airbnb_df
# Out:
#              id    host_id  latitude  longitude     price  minimum_nights  \
# 0          6369      13660  40.45724   -3.67688 -0.233947       -0.462245
# 1         21853      83531  40.40381   -3.74130 -0.603171        0.011593
# 2         23001      82175  40.38840   -3.69511 -0.361265        1.749001
# 3         24805  346366726  40.42183   -3.70529  0.173473        0.169540
# 4         26825     114340  40.38975   -3.69018 -0.666830       -0.304299
# ...         ...        ...       ...        ...       ...             ...
# 16003  49185822  172011610  40.40756   -3.69937 -0.705026        4.118193
# 16004  49186179  172011610  40.43706   -3.71364 -0.730489        4.118193
# 16005  49187258  172011610  40.43857   -3.70715 -0.717758        0.485432
# 16006  49187471  172011610  40.43027   -3.66759 -0.755953        4.118193
# 16007  49187791  172011610  40.43484   -3.70667 -0.743221        4.118193
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

minmaxscaler = MinMaxScaler()
airbnb_df[["availability_365"]] = minmaxscaler.fit_transform(airbnb_df[["availability_365"]])
airbnb_df
# Out:
#              id    host_id  latitude  longitude     price  minimum_nights  \
# 0          6369      13660  40.45724   -3.67688 -0.233947       -0.462245
# 1         21853      83531  40.40381   -3.74130 -0.603171        0.011593
# 2         23001      82175  40.38840   -3.69511 -0.361265        1.749001
# 3         24805  346366726  40.42183   -3.70529  0.173473        0.169540
# 4         26825     114340  40.38975   -3.69018 -0.666830       -0.304299
# ...         ...        ...       ...        ...       ...             ...
# 16003  49185822  172011610  40.40756   -3.69937 -0.705026        4.118193
# 16004  49186179  172011610  40.43706   -3.71364 -0.730489        4.118193
# 16005  49187258  172011610  40.43857   -3.70715 -0.717758        0.485432
# 16006  49187471  172011610  40.43027   -3.66759 -0.755953        4.118193
# 16007  49187791  172011610  40.43484   -3.70667 -0.743221        4.118193
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %% [markdown]
# #### Insights:
#
# * The *price*, *minimum_nights*, *number_of_reviews*, *reviews_per_month* and *calculated_host_listings_count* columns have been handled using **StandardScaler** as the columns are skewed.
# * *availability_365* column has been handled using **MinMaxScaler** as the column is not skewed.
